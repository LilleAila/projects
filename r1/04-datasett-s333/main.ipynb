# %% [markdown]
# Data hentet fra https://seklima.met.no/observations/
#
# Data er gyldig per 26.03.2025 (CC BY 4.0), Meteorologisk institutt (MET)

# %%
import pandas as pd

# %%
df = pd.read_csv("hopen.csv", delimiter=";", decimal=",")
df
# Out:
#      Navn  Stasjon  Tid(norsk normaltid)  Middeltemperatur (år)
# 0   Hopen  SN99720                  1946                   -5.0
# 1   Hopen  SN99720                  1947                   -5.6
# 2   Hopen  SN99720                  1948                   -7.2
# 3   Hopen  SN99720                  1949                   -5.1
# 4   Hopen  SN99720                  1950                   -3.4
# ..    ...      ...                   ...                    ...
# 73  Hopen  SN99720                  2020                   -3.7
# 74  Hopen  SN99720                  2021                   -2.6
# 75  Hopen  SN99720                  2022                   -2.5
# 76  Hopen  SN99720                  2023                   -1.5
# 77  Hopen  SN99720                  2024                   -2.3
#
# [78 rows x 4 columns]

# %%
df["Middeltemperatur (år)"].plot()
# Out:
# <Axes: >
